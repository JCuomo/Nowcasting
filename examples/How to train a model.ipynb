# %% [markdown]
# # Train a model

# %%
import context
from mlnowcasting.train import train

# %% [markdown]
# All the parameters uses defautl locations

# %%
training_dataset = validation_dataset = 'example_dataset'
model_name = 'resConv_16_16'
# any of the available losses: mse, mae, logcosh, ssim, bce, b_mse_mae, combined, metric_loss
loss       = 'logcosh' 
params     = 'resConv_16_16'
# the model is saved automatically at the default location
model = train(training_dataset, validation_dataset, model_name, loss, params_module=params)
# Out:
# Train Epoch: 10 Loss: 0.055241 Val_Loss: 0.081546
# Training finished
